# %% [markdown]
# Riley's Analysis Notebook

# %%
import pandas as pd

# %%
dataset = pd.read_csv("./../../data/raw/listings.csv")

# %%
dataset.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20201210194755   2020-12-11
# 1  5858  https://www.airbnb.com/rooms/5858  20201210194755   2020-12-11
# 2  7918  https://www.airbnb.com/rooms/7918  20201210194755   2020-12-11
# 3  8142  https://www.airbnb.com/rooms/8142  20201210194755   2020-12-11
# 4  8339  https://www.airbnb.com/rooms/8339  20201210194755   2020-12-10
#
#                                                 name  \
# 0              Bright, Modern Garden Unit - 1BR/1BTH
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                          description  \
# 0  Cleaning Protocol: Our cleaners follow the Air...
# 1  <b>The space</b><br />We live in a large Victo...
# ...
